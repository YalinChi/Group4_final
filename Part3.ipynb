# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# For ArcGIS visualization

# %%
# Read historical weather and weather station datasets
his_weather = pd.read_csv('D:/group4/predict-energy-behavior-of-prosumers/data/historical_weather.csv')
station = pd.read_csv('D:/group4/predict-energy-behavior-of-prosumers/data/weather_station_to_county_mapping.csv')

# %%
# Merge historical weather and weather station based on latitude and longitude
merge3 = pd.merge(station, his_weather, on=['longitude', 'latitude'], how='left')
merge3
# Out:
#        county_name  longitude  latitude  county             datetime  \
# 0              NaN       21.7      57.6     NaN  2021-09-01 00:00:00
# 1              NaN       21.7      57.6     NaN  2021-09-01 01:00:00
# 2              NaN       21.7      57.6     NaN  2021-09-01 02:00:00
# 3              NaN       21.7      57.6     NaN  2021-09-01 03:00:00
# 4              NaN       21.7      57.6     NaN  2021-09-01 04:00:00
# ...            ...        ...       ...     ...                  ...
# 641617         NaN       28.2      58.5     NaN                  NaN
# 641618         NaN       28.2      58.8     NaN                  NaN
# 641619         NaN       28.2      59.1     NaN                  NaN
# 641620         NaN       28.2      59.4     NaN                  NaN
# 641621         NaN       28.2      59.7     NaN                  NaN
#
#         temperature  dewpoint  rain  snowfall  surface_pressure  \
# 0              14.2      11.6   0.0       0.0            1015.9
# ...

# %%
# Export to csv for further ArcGIS visualization
merge3.to_csv('D:/group4/predict-energy-behavior-of-prosumers/data/final_merge2.csv',index=False)
